# %%
from  modular_program import *
#make object and pass it's data members
samples = [ DataSample("SampleA", [10, 20, 30]), DataSample("SampleB", [5, 15, 25, 35])]
for s in samples: 
    s.display() 
    print(s.summary())
# Out:
# Sample name:Sample1
# DataSample:[1, 2, 3, 4, 5]
# Summary:
# Sample name:SampleA
# DataSample:[10, 20, 30]
# Summary:
# {'mean': 20.0, 'max': 30, 'min': 10, 'range': 20, 'variance': 100.0, 'SD': 10.0}
# Sample name:SampleB
# DataSample:[5, 15, 25, 35]
# Summary:
# {'mean': 20.0, 'max': 35, 'min': 5, 'range': 30, 'variance': 166.66666666666666, 'SD': 12.909944487358056}
